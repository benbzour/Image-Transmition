# %%
# Import functions and libraries
import numpy as np
import matplotlib.pyplot as plt
import queue as Queue
import time
import sys

from numpy import pi
from numpy import sin
from numpy import zeros
from numpy import r_
from numpy import ones
from scipy import signal
from scipy import integrate
from scipy import misc
import threading

from numpy import mean
from numpy import power
from numpy.fft import fft
from numpy.fft import fftshift
from numpy.fft import ifft
from numpy.fft import ifftshift
import bitarray
from  scipy.io.wavfile import read as wavread
import newax25 as ax25

import multiprocessing

from math import gcd
import sounddevice as sd
import RPi.GPIO as GPIO
from functools import reduce
from numpy import ones,zeros, pi, cos, exp, sign




# %matplotlib inline

# %%
# function to compute least common multipler
def lcm(numbers):
    return reduce(lambda x, y: (x*y)//gcd(x,y), numbers, 1)

# %%
sd.query_devices()
# Out:
#   0 bcm2835 ALSA: - (hw:0,0), ALSA (0 in, 2 out)
#   1 bcm2835 ALSA: IEC958/HDMI (hw:0,1), ALSA (0 in, 2 out)
#   2 USB Audio Device: - (hw:1,0), ALSA (1 in, 2 out)
#   3 sysdefault, ALSA (0 in, 128 out)
#   4 dmix, ALSA (0 in, 2 out)
# * 5 default, ALSA (1 in, 2 out)

# %%
builtin_idx = 0
usb_idx = 2
sd.default.samplerate=48000
sd.default.channels = 1

# %%
GPIO.setmode(GPIO.BOARD)
PTT = 12
GPIO.setup(PTT, GPIO.OUT, initial = 0)
GPIO.output(PTT, GPIO.LOW)

# %%
import numpy.ctypeslib as npct
from ctypes import c_int
from ctypes import c_float

array_1d_int = npct.ndpointer(dtype=np.int, ndim=1, flags='CONTIGUOUS')

libcd = npct.load_library("./libpll", ".")
libcd.pll.restype = c_int
libcd.pll.argtypes= [array_1d_int, c_int, array_1d_int,array_1d_int,  array_1d_int,array_1d_int, c_int, c_float]



class TNCaprs:
    
    def __init__(self, fs = 48000.0, Abuffer = 512, Nchunks=10):
        
        #  Implementation of an afsk1200 TNC. 
        #
        #  The TNC processes a `Abuffer` long buffers, till `Nchunks` number of buffers are collected into a large one.
        #  This is because python is able to more efficiently process larger buffers than smaller ones.
        #  Then, the resulting large buffer is demodulated, sampled and packets extracted.
        #
        # Inputs:
        #    fs  - sampling rate
        #   TBW  -  TBW of the demodulator filters
        #   Abuffer - Input audio buffers from Pyaudio
        #   Nchunks - Number of audio buffers to collect before processing
        #   plla    - agressivness parameter of the PLL
        
        
        ## compute sizes based on inputs
        self.TBW = 2.0   # TBW for the demod filters
        self.N = (int(fs/1200*self.TBW)//2)*2+1   # length of the mark-space filters for demod
        self.fs = fs     # sampling rate   
        self.BW = 1200      # BW of filter based on TBW
        self.Abuffer = Abuffer             # size of audio buffer
        self.Nchunks = Nchunks             # number of audio buffers to collect
        self.Nbuffer = Abuffer*Nchunks+(self.N*3-3)         # length of the large buffer for processing
        self.Ns = 1.0*fs/1200.0 # samples per symbol
        
        ## state variables for the modulator
        self.prev_ph = 0  # previous phase to maintain continuous phase when recalling the function
        
        ##  Generate Filters for the demodulator
        self.h_lp = signal.firwin(self.N,self.BW/fs*1.0,window='hanning')
        self.h_lpp = signal.firwin(self.N,self.BW*2*1.2/fs,window='hanning')
        self.h_space = self.h_lp*exp(1j*2*pi*(2200)*(r_[0:self.N]-self.N//2)/fs)
        self.h_mark = self.h_lp*exp(1j*2*pi*(1200)*(r_[0:self.N]-self.N//2)/fs)
        self.h_bp = signal.firwin(self.N,self.BW/fs*2.2,window='hanning')*exp(1j*2*pi*1700*(r_[0:self.N]-self.N//2)/fs)


        ## PLL state variables  -- so conntinuity between buffers is preserved
        self.dpll = np.round(2.0**32 / self.Ns).astype(np.int32)    # PLL step
        self.pll =  0                # PLL counter
        self.ppll = -self.dpll       # PLL counter previous value -- to detect overflow
        self.plla = 0.74             # PLL agressivness (small more agressive)
        

        ## state variable to NRZI2NRZ
        self.NRZIprevBit = bool(1)  
        
        ## State variables for findPackets
        self.state='search'   # state variable:  'search' or 'pkt'
        self.pktcounter = 0   # counts the length of a packet
        self.packet = bitarray.bitarray([0,1,1,1,1,1,1,0])   # current packet being collected
        self.bitpointer = 0   # poiter to advance the search beyond what was already searched in the previous buffer

        ## State variables for processBuffer
        self.buff = zeros(self.Nbuffer)   # large overlapp-save buffer
        self.chunk_count = 0              # chunk counter
        self.oldbits = bitarray.bitarray([0,0,0,0,0,0,0])    # bits from end of prev buffer to be copied to beginning of new
        self.Npackets = 0                 # packet counter
        
        
    
    
    def NRZ2NRZI(self,NRZ, prevBit = True):
        NRZI = NRZ.copy() 
        for n in range(0,len(NRZ)):
            if NRZ[n] :
                NRZI[n] = prevBit
            else:
                NRZI[n] = not(prevBit)
            prevBit = NRZI[n]
        return NRZI
    



    def NRZI2NRZ(self, NRZI):  
        NRZ = NRZI.copy() 
    
        for n in range(0,len(NRZI)):
            NRZ[n] = NRZI[n] == self.NRZIprevBit
            self.NRZIprevBit = NRZI[n]
    
        return NRZ
    
    def KISS2bits(self,KISS):
        # function that takes a KISS frame sent via TCP/IP and converts it to an APRSpacket bit stream.
        
        bits = bitarray.bitarray(endian="little")
        bits.frombytes(KISS)
        fcs = ax25.FCS()
        for bit in bits:
            fcs.update_bit(bit)
            
        bits.frombytes(fcs.digest())
        return bitarray.bitarray('01111110') + ax25.bit_stuff(bits) + bitarray.bitarray('01111110') 
     
    def bits2KISS(self,bits):
        # function that takes a bitstream of an APRS-packet, removes flags and FCS and unstuffs the bits
        bitsu = ax25.bit_unstuff(bits[8:-8])
        return  bitsu[:-16].tobytes() 
    
    
    def modulate(self,bits):
    # the function will take a bitarray of bits and will output an AFSK1200 modulated signal of them, sampled at fs Hz
    #  Inputs:
    #         bits  - bitarray of bits
    #         fs    - sampling rate
    # Outputs:
    #         sig    -  returns afsk1200 modulated signal
    
        fss = lcm((1200,self.fs))
        deci = fss//self.fs
    
        Nb = fss//1200
        nb = len(bits)
        NRZ = ones((nb,Nb))
        for n in range(0,nb):
            if bits[n]:
                NRZ[n,:]=-NRZ[n,:]
    
        freq = 1700 + 500*NRZ.ravel()
        ph = self.prev_ph + 2.0*pi*integrate.cumtrapz(freq)/fss
        sig = cos(ph[::deci])
        
        return sig 
    
    def modulatPacket(self, callsign, digi, dest, info, preflags=80, postflags=80 ):
        
        # given callsign, digipath, dest, info, number of pre-flags and post-flags the function contructs
        # an appropriate aprs packet, then converts them to NRZI and calls `modulate` to afsk 1200 modulate the packet. 
        
        packet = ax25.UI(destination=dest,source=callsign, info=info, digipeaters=digi.split(b','),)
        prefix = bitarray.bitarray(np.tile([0,1,1,1,1,1,1,0],(preflags,)).tolist())
        suffix = bitarray.bitarray(np.tile([0,1,1,1,1,1,1,0],(postflags,)).tolist())
        sig = self.modulate(self.NRZ2NRZI(prefix + packet.unparse()+suffix))

        return sig
    
    

    def demod(self, buff):
        #Demodulates a buffer and returns valid NRZ
    
        SIG = np.convolve(buff,self.h_bp,mode='valid')
        NRZ = abs(np.convolve(SIG,self.h_mark,mode='valid')) - abs(np.convolve(SIG,self.h_space,mode='valid'))
        NRZ = np.convolve(NRZ,self.h_lpp,mode='valid')
        return NRZ


    def FastPLL(self,NRZa):
        recbits = np.zeros(len(NRZa)//(self.fs//1200)*2,dtype=np.int32)
        pll = np.zeros(1,dtype = np.int32)
        pll[0] = self.pll
        ppll = np.zeros(1,dtype = np.int32)
        ppll[0] = self.ppll
        
        #print("pll = ",pll,"   ppll=",ppll)
        
        
        NRZb = (NRZa > 0).astype(np.int32)
        tot = libcd.pll(NRZb,len(NRZb),recbits,recbits,pll,ppll,self.dpll,self.plla)
        
        self.ppll = ppll.copy()
        self.pll = pll.copy()
        
        #print("post: pll = ",pll,"   ppll=",ppll)
        
        return bitarray.bitarray(recbits[:tot].tolist())
    
    def PLL(self, NRZa):
       #print("running PLL")
        idx = zeros(len(NRZa)//int(self.Ns)*2)   # allocate space to save indexes        
        c = 0
        
        for n in range(1,len(NRZa)):
            if (self.pll < 0) and (self.ppll >0):
                idx[c] = n
                c = c+1
        
            if (NRZa[n] >= 0) !=  (NRZa[n-1] >=0):
                self.pll = np.int32(self.pll*self.plla)
            
        
            self.ppll = self.pll
            self.pll = np.int32(self.pll+ self.dpll)
    
        return idx[:c].astype(np.int32) 
    
   

    def findPackets(self,bits):
        # function take a bitarray and looks for AX.25 packets in it. 
        # It implements a 2-state machine of searching for flag or collecting packets
        flg = bitarray.bitarray([0,1,1,1,1,1,1,0])
        packets = []
        n = self.bitpointer
        
        # Loop over bits
        while (n < len(bits)-7) :
            # default state is searching for packets
            if self.state is 'search':
                # look for 1111110, because can't be sure if the first zero is decoded
                # well if the packet is not padded.
                if bits[n:n+7] == flg[1:]:
                    # flag detected, so switch state to collecting bits in a packet
                    # start by copying the flag to the packet
                    # start counter to count the number of bits in the packet
                    self.state = 'pkt'
                    self.packet=flg.copy()
                    self.pktcounter = 8
                    # Advance to the end of the flag
                    n = n + 7
                else:
                    # flag was not found, advance by 1
                    n = n + 1            
        
            # state is to collect packet data. 
            elif self.state is 'pkt':
                # Check if we reached a flag by comparing with 0111111
                # 6 times ones is not allowed in a packet, hence it must be a flag (if there's no error)
                if bits[n:n+7] == flg[:7]:
                    # Flag detected, check if packet is longer than some minimum
                    if self.pktcounter > 200:
                        #print('packet found!')
                        # End of packet reached! append packet to list and switch to searching state
                        # We don't advance pointer since this our packet might have been
                        # flase detection and this flag could be the beginning of a real packet
                        self.state = 'search'
                        self.packet.extend(flg)
                        packets.append(self.packet.copy())
                    else:
                        # packet is too short! false alarm. Keep searching 
                        # We don't advance pointer since this this flag could be the beginning of a real packet
                        self.state = 'search'
                # No flag, so collect the bit and add to the packet
                else:
                    # check if packet is too long... if so, must be false alarm
                    if self.pktcounter < 2680:
                        # Not a false alarm, collect the bit and advance pointer        
                        self.packet.append(bits[n])
                        self.pktcounter = self.pktcounter + 1
                        n = n + 1
                    else:  #runaway packet
                        #runaway packet, switch state to searching, and advance pointer
                        self.state = 'search'
                        n = n + 1
        
        self.bitpointer = n-(len(bits)-7) 
        return packets

    
    # function to generate a checksum for validating packets
    def genfcs(self,bits):
        # Generates a checksum from packet bits
        fcs = ax25.FCS()
        for bit in bits:
            fcs.update_bit(bit)
    
        digest = bitarray.bitarray(endian="little")
        digest.frombytes(fcs.digest())

        return digest




    # function to parse packet bits to information
    def decodeAX25(self,bits, deepsearch=False):
        ax = ax25.AX25()
        ax.info = "bad packet"
    
    
        bitsu = ax25.bit_unstuff(bits[8:-8])
    
        
        #foundPacket = False
        #if (self.genfcs(bitsu[:-16]).tobytes() == bitsu[-16:].tobytes()):
        #        foundPacket = True
        #elif deepsearch: 
        #    tbits = bits[8:-8]
        #    for n in range(0,len(tbits)):
        #        tbits[n] = not tbits[n]
        #        if (self.genfcs(bitsu[:-16]).tobytes() == bitsu[-16:].tobytes()):
        #            foundPacket = True
        #            print("Success deep search")
        #            break
        #        tbits[n] = not tbits[n]
        # 
        #if foundPacket == False:
        #    return ax
        
        if (self.genfcs(bitsu[:-16]).tobytes() == bitsu[-16:].tobytes()) == False:
            #print("failed fcs")
            return ax
                  
    
        bytes = bitsu.tobytes()
        ax.destination = ax.callsign_decode(bitsu[:56]).decode('ascii')
        source = ax.callsign_decode(bitsu[56:112]).decode('ascii')
    
        if source[-1].isdigit() and source[-1]!="0":
            ax.source = "".join((source[:-1],'-',source[-1]))
        else:
            ax.source = source[:-1]
    
        digilen=0    
    
        if bytes[14]=='\x03' and bytes[15]=='\xf0':
            digilen = 0
        else:
            for n in range(14,len(bytes)-1):
                if bytes[n] & 1:
                    digilen = (n-14)+1
                    break

        #    if digilen > 56:
        #        return ax
        ax.digipeaters =  ax.callsign_decode(bitsu[112:112+digilen*8]).decode('ascii')
        ax.info = bitsu[112+digilen*8+16:-16].tobytes()
    
    
        return ax

    def processBuffer(self, buff_in):
        
        # function processes an audio buffer. It collect several small into a large one
        # Then it demodulates and finds packets.
        #
        # The function operates as overlapp and save
        # The function returns packets when they become available. Otherwise, returns empty list
        
        N = self.N
        NN = (N*3 -3 )
        
        
        Nchunks = self.Nchunks
        Abuffer = self.Abuffer
        fs = self.fs
        Ns = self.Ns
        
        validPackets=[]
        packets=[]
        NRZI=[]
        idx = []
        bits = []
        
        # Fill in buffer at the right place
        self.buff[NN+self.chunk_count*Abuffer:NN+(self.chunk_count+1)*Abuffer] = buff_in.copy()
        self.chunk_count = self.chunk_count + 1
        
        
        # number of chunk reached -- process large buffer
        if self.chunk_count == Nchunks:
            # Demodulate to get NRZI
            NRZI = self.demod(self.buff)
            # compute sampling points, using PLL
            #idx = self.PLL(NRZI)
            # Sample and make a decision based on threshold
            #bits = bitarray.bitarray((NRZI[idx]>0).tolist())
            
            bits = self.FastPLL(NRZI)
            # In case that buffer is too small raise an error -- must have at least 7 bits worth
            if len(bits) < 7:
                raise ValueError('number of bits too small for buffer')
            
            # concatenate end of previous buffer to current one
            bits = self.oldbits + self.NRZI2NRZ(bits)
            
            # store end of bit buffer to next buffer
            self.oldbits = bits[-7:].copy()
            
            # look for packets
            packets = self.findPackets(bits)
            
            # Copy end of sample buffer to the beginning of the next (overlapp and save)
            self.buff[:NN] = self.buff[-NN:].copy()
            
            # reset chunk counter
            self.chunk_count = 0
            
            # checksum test for all detected packets
            for n in range(0,len(packets)):
                if len(packets[n]) > 200: 
                    try:
                        ax = self.decodeAX25(packets[n])
                    except:
                        ax = ax25.AX25()
                        ax.info = "bad packet"
                    if ax.info != 'bad packet':
                        validPackets.append(packets[n])
                        
            
        return validPackets

# %%
callsign = "KM6QHD"
fname = b"calBlue.tiff"
# fname = b'rec.tar.bz2'
f = open(fname,"rb")

fs = 48000
modem = TNCaprs(fs = fs ,Abuffer = 512,Nchunks = 1)
    


Qout = Queue.Queue()



print("Putting packets in Queue")
npp = 0
tmp = modem.modulatPacket(callsign, b"", 'BEGIN', fname , preflags=80, postflags=10 ) 
Qout.put(tmp)
while(1):
    bytess = f.read(256)    

    tmp = modem.modulatPacket(callsign, b"", str(npp), bytess, preflags=40, postflags=10 )    
#     tmp = modem.modulatPacket(callsign, b"", 'BEGIN', b"calBlue.tiff" , preflags=80, postflags=10 ) 
    Qout.put(tmp)

    npp = npp+1
    if len(bytess) < 256:
        break
tmp = modem.modulatPacket(callsign, b"", "END", b"This is the end of transmission", preflags=10, postflags=80 )
Qout.put(tmp)


print("Done")
# Out:
# Putting packets in Queue
# Done

# %%
Qin = Queue.Queue()

print("Starting streams")
# st_replay.start()
starttime = time.time()
while Qout.empty()==False:
    tmp = Qout.get()
    GPIO.output(PTT, GPIO.HIGH)
    sd.play(0.15*tmp,samplerate=fs,blocking=True)
    GPIO.output(PTT, GPIO.LOW)
    
# st_replay.stop()
# st_replay.close()

print("Done")
print(time.time() - starttime)
# Out:
# Starting streams
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c1ab03b50e1b> in <module>()
#       5 # st_replay.start()
#       6 starttime = time.time()
# ----> 7 while Qout.empty()==False:
#       8     tmp = Qout.get()
#       9     GPIO.output(PTT, GPIO.HIGH)
#
# NameError: name 'Qout' is not defined

# %%
# Callback for receiving audio from radio and sotring the samples in a Queue

def queuereplay_callback(indata,outdata, frames, time, status):
    if status:
        print(status)
    outdata[:] = indata
    Qin.put_nowait( indata.copy()[:,0] )  # Global queue
st_replay = sd.Stream( device=(usb_idx, builtin_idx),callback=queuereplay_callback)



Qin = Queue.Queue()


# Start listening audio. 

st_replay.start()

# %%
# Start receiver


Abuffer = 512
Nchunks = 10
fs =48000
#modem = OLDTNCaprs(fs = fs,Abuffer = Abuffer,Nchunks = Nchunks)
#modem = TNCaprs(fs = fs,Abuffer = Abuffer,Nchunks = Nchunks, dec = 4)


modem = TNCaprs(fs = fs,Abuffer = Abuffer,Nchunks = Nchunks)
npack = 0
state = 0 
while (1):
        counter = 0
        while (Qin.empty()):
                if counter == 10:
                    st_replay.stop()
                    st_replay.close()
                    st_replay = sd.Stream( device=(usb_idx, builtin_idx),callback=queuereplay_callback)
                    st_replay.start()
                    counter = 0
                counter = counter + 1
                time.sleep(0.1)
                
        packets  = modem.processBuffer( Qin.get())
        for pkt in packets: 
            
            npack = npack + 1
            try:
                ax = modem.decodeAX25(pkt)
                #print(npack)
                infostr = "%(n) 2i) | DEST: %(dest)s | SRC: %(src)s | DIGI: %(digi)s | %(info)s |" % {
                        'n': npack,
                        'dest': ax.destination,
                        'src': ax.source,
                        'digi': ax.digipeaters,
                        'info': ax.info
                    }
                print(infostr)
                if state == 0 and ax.destination[:5]=="BEGIN":
                    f1 = open("rec_"+ax.info.decode(),"wb")
                    state = 1
                elif state == 1 and ax.destination[:3] == "END": 
                    state = 2  
                    break
                elif state == 1:
                    f1.write(ax.info)
                    print("write")
#             if state == 2 :
#                 break
            except:
                print(npack,"packet")
                
                

#             msg = b'\xc0\x00'+ modem.bits2KISS(pkt) +  b'\xc0'
#             connection.sendall(msg)
# Out:
#  1) | DEST: BEGIN 0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b'reczip.zip' |
#  2) | DEST: 0     0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x15\xab\x94L\xces\x84\xe0\xad\x11\x00\x00\x8cl\x00\x00\x08\x00\x00\x00rec.tiff\xed\\]h\\\xc7\x15\x96\x9bPJ\xdf\xf2\xd0\x86\x96\xe6!!\xc6F$XX\x08-{\xb9\xc30\x87\xb9\xec\xb2\xec"!dllLB\x8a\xfb\x10\x93R\x13\\RZ\x82MR\x0b!\xe1`#$VH,+V\x08\x0b\x89@\xa1\x90\xb7>\xf41\xb4\xb4\x94\x96\x96\x96\xd2PH)\x94<\x84>\xb7s\xe7\xee\x8c\xce\x9d9\xe7ZkKV\xfe>k\xd7w\xe7\xce\x9d9s\xe6\xcc\x99s\xce\xcc\xdcfs|\xec\x1bccc\xdf\x1c\x1b;\xf5\xf4\xd8)s\xf5+\xf395\xbc\x9e0\x9f\xaf\x9dzj\xec)\xf3\xff\xcf\xcd\xe7)s\x9d\xa7\xe7\x9f\xaf\x0f\xaf\xbff>\xcf\x0c\xf3/\x99\xcf\xb7\x86\xe9\xf93\xdfF\xe5<;\xbc\x1e\xbb>6\xf6=TN\x8eo\xd8\x7f\x9f\xae\r\xb2f:!@(%\xed_\x81\xbf,\xef\xd6@5\xfdo' |
# write
#  3) | DEST: 1     0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b'\x87\x8f\x17\xf6!L\xcb\xf1\xb7\xc5\xbd\x8cJ\xff\xd3\xc2\xbeB\xc5z|\xb0\xb0?\xafT\xd3\xde\xc2\x05~\xb8\xb47)\xe0\x1c\x0co\xf9\xbb\xbf\xbc\xbf\x93\x80\x9a\xb1?}\xa2\xb9\xd8[\xde\x9d\x07\xa9\xa3\xf2\xd7\x97\xf6H:W\x99t\x93_P\xe9{K{SJ\xe9\xa8\t\xffXz\xf0\xa2\x04\x88\xd2\xffwo\xbb\tR:\xf2\n\x98l\xffX\xde\x9d\x05Y\\\x03j\xf2\x9f\x16\xf7\x85\xcb\x8c\t\xfb\xfb\xc2~\x8a\x1e\xf7\xf8da\xbf\xee\x98\x80\xf1\xaf;\xfbs \r\x7f&\xed]O\xf0\xa7wh\xfe\xffga?f\x9a\xc1G\x0b\xfb\\?\xea\x88H\x83D*\x00\xd9\x86\xbcF\x8d\xeeNkY\x07\x99\xc90\x7f\x83"\xa6H\'\xfb\xa5\xe6\x84$\xc0YS\xbe\x1cV\x8a\xd1n\x88\xd3\x12ZJ\x05\xbd\xf9\xb3\xa60\xec\xef@\xa9+\xcd\xc5+\x99\xb8\x04D\xd5\xf5L\x92\xf4Lg$\xf9j\x92\xc9?\x9e\xc9\x8c\xa2\xffL&\xa7\x95\x8ao\xe9\x96\x88;\xd7\xa0\xd3J\xcd\r' |
# write
#  4) | DEST: 2     0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b"\xe1\xb8\xe4\xebzI\xcb&\x0c\x99\x80\t8\x03%\xf1;\xa0S\xa9\x94bu\xe28\x19T\x9dF9}~\x12u&=\xa5\x84G\xd9\xfe\xf5\x8f\xe0\xaa\r1E{\x0f\t\xbaW\xd4\x01\xc7\x02d\xb6\xde\xf8\xa99;x\xe3\xf4\xa6%\xa6\x19\xa9\x02\x93\x9f\x14\xe9\x06Y\xab\x95\xf3\x91\xd2[L9)\xe4\x8f\xc4zI\x83\x8a\xe97?\x8d\x92L\x14!\x12\x99\xd5\xb4d\xbf\x905\xd7\xa3\x91\xe5\xab q\xdc\xe9)\x12Q\x9c\xa7m\xe9?>\xf9\xe1\x9e\x92V\xb4\xe2!\xf6\x12#\xff\xc2\xfe\x91\xe5\x1c+\x043\xde\x8d\x92\x94\x11\xa9\xd2\xe6'\xf5F\xc6\xf0\x87l\xacb\x1a{\x82\xe0\x88\x81\xca~\x7f\xfc\xf29p\xf2\x96R\x93\xbe\xaf\xe2\xf8X\xfa\x08\xe3\x82|\x84\xd3\x1bGE\xcfIaT}uR \x8d\xbd\x8a\xf4Q\x85\xff\x08\xdbK\xaa\x8e\xcf\x1a?\xbf\x84\x90G\xa7\x15\xbf\xc2\x97\r\xc5\xf8\xf5\xf2#\xcb\xe9_\xe1\xa4\xf0\xdf\xcd\xde\xcb*w\xa5\xdbe\xff\xfd\xb7K{" |
# write
#  5) | DEST: 3     0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b"3\xce\x14\xc4s\xc4\x1f\x17\xf7\x14\xd5k\xbf[\xdc#\xa7\x92_\xe7\xe5\xc04\x84\xae\xca\xc2\xea\xf6\x15\x01\x99\n]\xd7\x85\xeeV\r\xa4\x96\x10\x18<\x8b\xdd\xed9\x1b\xa4\x9a.\xc7\x85\xde]\xdd\x99\xcc\xf3\x87\x06\xc9\xbb\xf7\x1f\x98\x9f\xa6j]\xd6Z\xf7\xef>H@M\xc3\xb0p_\xfe\xcd\xb5\xc1\x9c\x84\xa6\x0cg\x9f\x9b\xdd\x810\x9e\xbd\xf5\x9e\x1a\x88\xd4[\xdd\xc1,j\x8f\xbf|\xbbk\xcaQuW\xe9\x01\xfd\xab;\xa6\xd2q\xcb\x87\xc2\x10*\x1a\xbe\xb2\x92\xc7\xb5$2\xf0\x8a\x07\x7f}w\xd70g\x12\x0e\xea(\xea\xfd\xfb\xe2\x9e\xb4\xdeM\xe0\xcd\xfd\xf3\xce~\x0bd\xc7:n\x98\x9f\x9f0\xf1\x9f\x7f\xdf\xd9\xcf\xa8\xa9\xf6\xcfK{\x02d\xaa\xc2\xd0\xca\x1f\x16\xf6\xdb\x12j\x10\x1a\x0c\xd2\x86=\xce\xdb\xfe\xc2\xa5uL\xe6\x889\x8a\xf7\x178;\xe4\xaa\x84q\x90q\x08\xe8'\xf5l^I#*\x81U\xf9z=k8:\xf1-\x9dfS0\xcc\x0f\xa8wf\xeb\xba" |
# write
#  6) | DEST: 4     0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b"\x90\x85 dw9\x01,f\x9e\xe6\xab)H+o\x01\xeb^I\xb5)\xb9-K\x0e\x8e\xb9\xb8\x98\x82\x91\x13SV\xcd\xb6\xdd\xe3\xb5D\xb7Lf+W~h\x98\xef\xeb)\xbc\x92\xd3/\xb32O^K\xa1\xed\x06\x05\x8e\x02\xddHa\x1a\xfd\xf4j\xf6\xddD\x9b\x92[\x1201y9\xf6\xbf\x9a\x1aF\x0f\xfc\xad\x16\xd3/\\\\\xc2Gn\x83~1\x83\xb4i\x07\x9d,\xf3\xdfp\xa6\x0eD\xbcK!?T8\xe2\xc1\xd6+\xe0\xe0\xaeG\x10>}(\xea6\x88\xed\xd9\xe2\xd1\xb1\xcc\x8c\xa3[WR-\xa9\x90\x82\xd1\x90q\x88\xd2\xdcm\xe4\xf1\xcf0\xb3AK\x1c(O\x81X\xa1\x154,\x7fDy\xfc\xce\xe5\xe1\xc9\x90\x9f\xe6z\xce\x06\x99a\xf8\xecAC\x8c\xf2\x9c\x91\xc3\xc25\x12\x80\xab2Wz\t\xa2\xa7\xf8\xbe\x9c\x9aJsa\xcb\\\xce\x82\xbc\xd7S\xad\x9dD\t\x94\x7f\\\x0f%0h\xf2\xa4\xfd\x9d\xb9\x80\x9eB\xa5\x91\xa8H'\x9f\xca\xd9\x02\xc4\x83\x85" |
# write
#  7) | DEST: 5     0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b'\xfa\x8dC\x10Xg\xe2[\x02\xb5\xf1\x90$\x91\xf0\xc2\x19S;\xe5\x08\xc0\xe8\xc8!s\x82\xf9\x0e\xec\xa0\x13\xe8\x91\xe2\xbb\x18,8\xb1\xa0\xd9\xa4\x17b\x13\x04ZS\xd7\x83:jo\x1cG\x95\x96iY\xe4\xad\xe7re/\x12\'\xa2\xfe\x91\x0bVc\x04\x9d\xab\xec\xf8\x9d\x89\\xpU\x04K\x18^\xf0\xe2(q\xb3\xdc|\\\x14\x89\x8at\xb2\x1f\x05\xca\xe0\x9f\x95\x88\ta\xbc\x8b\xd1\'\\\xfcjT\x00#<^Hb>\x90\xf4\xb4\x98\xbbX\xe7c\xf8.\x08\x1a\xa2\x99\xd0\r7/g\x11\'qz\xb0\x98\x02\xe5kOX\xc5\xfc\xe2\xa9\n\xee6\\z\x00y\xcc\xf1.<G\x07\xaa8\x0e\xb6+\x9e\x98\xa3\xa2\x90\x93Cr\x91N\x955$~0+w\xa5\'\xcf\x8f\x17\x89dU\xb9\xf6\xc6\xa2\x98\x96\x1f\x7f(\xf1\x9aaQR\x1e\xaa>C\xea\xe4\x13\xa2\xfc~\x85\x11\x97&\x90H\xe0\xd6\x05\xe6\x1c&i$\xfbaTp\x9c\xa9\x98"+\x9ez\x02\x08\xaa\x8e' |
# write
#  8) | DEST: 6     0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b'W\x18}z5\xeb\x0e\xc9\xd2\xc3\x0c^\x9c\x81\x1ctA\xb6`\x1e\xac\xc8L\x12\t\xe8/.0\xce\xac\x8e\xb3\xbfNP\x12\x1e\x01\x15\xf3f Ed\xbfT\xcb\x8c\x8c.\xd4c\x0f^<%\x8dj\xb2z\x02\xbeH\xf8x\xd0\x9d\xc8\xc4\x9c\x96\xf5\xb2a\xf0\xe7\xf7v.5\xd2y-\x03\xaf\xe7\x83\xe5\xdd\xcb\xc6\xbf\x80P\xa1\xdd^\x1d\xa4.\xd8\x82\xd3\xafo\xf4[\xc6u\x8d&\xd0\x1b\x9b[m\xa5\xb5\x0b5(\xd7\xb3?\xed\xf5ky\xbcE\x05\xd1\x89\xb7\xfa\xfdY\xa5\xbd\xff\xee\xf1\xe3^\x1f@\x9eE\x1b\x18\n\xbc\xbd\xbe5\tr\xdeN(\xd8\n\xbd\xb51H\xf3\x1d+\x00ek\xfc\xee\xca\xced\xbee%\xbf\xc6\xf4\xbf\xd5\xddj!\xd7\xcf\x7f_\xdb\xecM8\xeb\x1a\xcf576\xfbSH\x9fx\xb1\xbf\xd9\x1d\xb4l\x1c#\xb0\xf3\x7f\xb0>\x90n\xb5\x1a\xb7\xebG\xfd\r!s\x97\x1f\xca\xd6\xd1\xb5\x8d\xad\x16\xda-\xe3I]xo\xb7\xa6\xd3\x1a\x94:Q\xe6' |
# write
#  9) | DEST: 7     0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b'\xf1\xae\xf7\x9343|\xab\xa1\xfc&\xc3\xce\xbd]\xb0.C`H,\xacn_\xb2\x17i\xd9E\xbd\xb16\xb8(\xe0\xbc\r1\x01jrK\xe6\xd1\xab\xa6mB\x8a\x1c\x01#\x0c\x89ua\x82}AW\x84z9\x0fn@`\xd8\xbcS\xcb\x8a\xdf\x81\xfc\x18\x7f\xfc\x82\x80xJ\xcaR\x9d\x959P\\_\xb0q\x18\x856\x1a\x15O]\x90y\xa8j\xda:\x978}&\xdf\xa1$\xb1B\x00g\xd96\xed\xe6%,<\xf9O\xbb=d\xc6\xfe\xc4\xb6\xd3d\xce\nb?\xd2Y-\x8d\\5\xcb\xa4B\xcev\x98r?\xb1!tI\xe6EI\x087J]\x14z\x1c\xe4\x94\xed2\xcc\xd2\xab"\xaf\xb0\x8d\xea-\xd2\xafkQ\xc8\x8f*\x8b\xd65\xa1q\xd0\xd5Wq3\xc9\x9aJ\x8a2s\xf2zk\xadTd\x99\x8d\x8f\xe1\xa6]O\xa1\x89\x9a\xefqY\xaa\xc4\xee\xc7\x0b\xf8\xf0\xaa\r\xf6\x16q\xb9\xc2\x86\xc4\x04{\xd3\x02[n\x10\x05I\n^\x91A\xa49\t\x19\xb2R' |
# write
#  10) | DEST: 8     0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b'|\x06\xd3\x89\x17\xe5\xd0\xcf\xc5"7\xa9\xc5\xf40\xd2p`@J\x17^\xeeDz\xbe\tFC\xcazd$4$=\xb5\x9d7"W\x9ee\x8a\x8b)\x1bzJ\x10\x07\x8ata\xf7\x1d\xa5Q\xd3.Z\x7f<)\x17\x056\xb2\x9d"\xeey\xd4m\xd5\x8d\xb21\xaf\xdc\xfe\x8dx\x17\x076\xeaJ~\xa2\xd5\xb41\xab[6\x8e\x17[S\x1d\x10\r\t\xcd\x88\x9eF\xaa\xa7\xac|6P\xcf\xe6\xf9\x95\xcc\\\x13pQ\x97\x04\x18\xbd\xed\xe9\xf1\xe9\xf3\x12\n\xbe\x05\xfa\xdf\xc7\xd6t$QA\xc9\xd5H\x9c\x7f\x14\xdb\xc3\r\xca\xeb\xa91.\xc6yK\x06\x0e\xb2\r\xdb\xa5\xa0\x13\xc5C$\xf2\xbb\x03\xfd\xef\x97\x03t9\x7f\xdb\xdd\xca\xca\xa28\tC\xad\x15\xc0+\xe4\xc0\x88\x92LHd\xc6\x0e\x01/<\xfe[Z\x17>\x08\tJ\xc4\xf6 \x94*\x99xK\x8a\x84\x1c\xb7\xb7\xe1J\x0bFS\x1b\xb9\x84A9E!A\x93;n\xabI@g\xc7\x16\xa5(\x87:v\x1bU' |
# write
#  11) | DEST: 9     0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b'\xd4\x1d\xb8]\xa4+7M\r^\xe5\xf8\xa0\xa8[\xb1k\x03(r\x18\xd09\xe3\xd2q\xa7\x83\xd5\'d\x10\xc9\xd3\x13\x0c\xf6\xc9rK!\xfa\x8b\xe9W\x14\xd3\x12\xf7x\x80\x0eR\xc2\x18\x85\x19\x16\xc7\xdb[\x0cK\x9bL\x1c@Q\xedUNrH\xd3=\xa3\xba\xa0\xcelaM\xcb\xf2p\xe4 \x85GU\xfa#\xe4\xfc\x920\xedm2E\x01\x93\xbf\x81D\x94\x1c\x8f\xaa\xfcTB\xc9\xadr3K\x85\x90\xc7"J.\xf9\xa5n\x08\xc4t\x02%*\x9a\xdf\x97\x18\x0b\xa1\x8a\x96\x9b=\x12~\xc8\x93[\xa05\xb34&\xa3\x8b\x02\xc7\xbd\xef\x91\x1c\x14\x18\xc1\xdd\ny\x93\x14+b\xcf\xae\x00\xb7\x0fP\xa2*Jv\x05Su\x05s\xc8\xf2c\x89}(I\x0f\xa5\x93$\x89#5\xe6\'\t\xae_\xb8\xce\x92\x8c>O\x19=0*\xc8Aq\x18\xc4$\x8dT\x057\xb8\xb8r\xbcQ\x140\x16{\nAz5U\x87D\xecT**\x05\xca\xd7\x15C\xe9\x90\xa2^!\x0fG' |
# write
#  12) | DEST: 10    0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b'\x92\xae\x98.\xf8\xfd\xa0{F\xc1\x0bi&\xe4AC\xcc\xf7_\xbb[7\x9b\xc9ttJ\xe2\xcd\x8dAG\xc0\x1c\xb2r\x87\xe9\xbd\xfe\x15\x05\x00\xe1\x86\xf6\xdb\x0f\xd6/7\xc4\x8c\x8b\xf3x\x1a\xde\xd9\xebj-\xcf\xa5:\xf0"o\xf4{\xd3\xa9\xee\xb88\x8f/\xe7\xcd\xad\xcd\x8e\x16\r\xb4\x8aQ\xdc\xba\xd4\xeb\xf9\xa9\x10\xd3\xf9\xfa\xfa\xd6\xb86.\x95\x0cF\xd3\x0f7\xfaJ\xe8\x8b\x91+\xb7\xbe\xd1\x93\x8d\x04\xa2\xa5\xcc\x0f\xee\xed\xf8\xa9\r\x97\xff\xfe\xfdmr\xc9lyu0cOg@y\xa2\xbc\xb7\xb2]\xa3\xb4\xcd\xed\xb5A\x117P\xe5\x0eZ[\xdd~\xc9\xfa\xfbI\xd9;{\xa3\xbbu#\xd5s2\x94\xba\xcb\x9b\xfd\x97\xdc*!N\xbf\xb6\xd9\xefP2\xf1\xeaF_\xb8\xa3.\xf8~g\xb3\x9fR~\xdf\xab\xdd\xadsvS\n\x94\xfb=\xef\x11\xd3Y\x90\x1b\x9c\xd8z\x97v\xf7F\xc7\x86\x02\xb0\xaen\xe9|\xc7P\xb1k\x08Wq^\x82\xf9\xd3.\x84\xe8\xd1' |
# write
#  13) | DEST: 11    0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b'N\x1a\x93\xe9\xb0B\x9c^\xaf7\x9a\xc6%\xccD`*\\\x95 \xe4\x90\t\xb8u&\xdd\xf8\xef\x89<\x08%\x15\xe9\xa9=\xaa\x13s\xe8\xb9L\xcc\xe7\xc4@p\xeb\xb4\x96\xd36\x98\x16\xf8\x17\x93\n2I\xc8\xc9\xb8\xa2\xc7\xe4\x99L\x90C\xfe\xe9\x86\xf0v\x0e\xcep*\x13\xe4\x11\x80\xb1L\xe0\xf0\x91\xc73\x99\x98\xb2\xbf\x83\xd9p\xda\nU<\xc5\x14\xfb\xacZQ\x15W\xed\x08\x8d\xb7\x82\xcc\tM\x9a\x04Y\x14\x89-\x90\xda\x90\x85\x88&\xb8B\xd2\x1aXr\\\x99x\x87\x9bW\xef\x17`\xb8\x89%hW\x1d\xe4E\x05\xb3Q\xbd\x13\x12\xda6#\x1eD\x06fp%rH\x18\xc6i5dB<\xbf\x9f\xa5\x8e\x8cI\x90$\x1f:Q\xe4\xb9\x80p.m`E\xd7\x14\xbc\x1c\x9dw\x93V\x93\x90\xeb\xb0\ts8.w\t\x81\xb0\xdb\x8b\xcdWq\xbf\xcf2\xae\xeb\x04\xe4\xb7\xda\x91\x0b\xa0\xd1\x91=\\T\x11\xb7\x8cC(\x05\xe5\xad\xa8\xea\\\xc9\xb8}b\x81}\xa8' |
# write
#  14) | DEST: 12    0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b'\xa8\xd5\xed\xc4nA\t\xac \xef&s&_,\x87\xb3\xce\x9a\n\xf2\x17A\xf5$\xea\xb2q{\xa8\x16\xf3\xbfh\xdd\xb4\x16\t\xe5\xf5<\x8b\x0e#\x97\xe4S\xa9sQ\xa2w\xbaI\xbb\x9a\xb4\xa327\x82d(?CQ\t\x9a\\gL\\\xce\x1fi1\xf9[\x8c\xbf\xc6\xed\xeb\xf0;\x0c\x83\xbb\x13n\xd1!\x90\xab\x06\xb3\x1f\xa6\xc8@\xc6\xb5\x80\x1a\x17**\x19\x17\x15\x0f\x99`\x07K\\u\x80\x19\xc6\xcf\xcd\x9c\xbe\n\xe89\xcf\x1c\xdd"-C(\x9f\x93\xc2E%n\xebW\xec\xffr\xf6$yK3\xfe\xac`XM6\xb6\x1a\xa4\t\xed)\x0f\xd2\xeb\xcc\xd6#\xee\\\xa4b\xd2c\xc9\xc7\xa8\xf0\xef\xe2\xc4j{\xfe\x90\xe0\xecy\xce\xbf\x08\xa6\'\x0f\xc1\x1c\xa9\xe6\xfc\xcav\xa5+\x1a\xcbOu\x8b\xe2*\xb8\x1d\x98\x15\xce)\xe7w\x8f\x04\xae_\xb8\xaa+\xe2!@\x11\xc0\xf9\xc5df2\xa5\x80?W\x1b\x97\xf6\xc8\xaewLO\x0cN\x89i&T\x12OR' |
# write
#  15) | DEST: 13    0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b'\xc5\x83\xdc\xbe2u\x88\x10\xd3aP\xdd)\xaaL\xff#T7\xaa\x1f\xcd\x81S&\x15\xf2\xc0\xdd\x1a\t\x15B\xf2\x98%\x1f\x9e\x00\x0cn2\xe5\x1a\xcb\xe91,\x9f\x87\xd7?$\x00q\xa9b\xcc>\x19T\xf7\xd7\x93\xe9\xb2\xc3\x80\xb3m>|\xd0\x9d2\xae\\\xf9<\x8b\xb9\xf8\xcd\xce\xfa\xbc\x16\xcf\x8b\xd0uZ\xda\xd9l\xcaa\x9c\x01\xe3V\x9e\x9e\x1f\x8d\t\x18\xb2\xf0\x8b\x95DK\x81f\x9f\xe2\xee\xed\x9d\x8dVC\xb4\xa5\xf2G\x15\x8a[\xb76\xfb-\xeb\xc2\xa7e]tk\xa3o\\\x9e\xef\xdb%`<!\xfebm@\xfa/\x7f\xbc\xbfc\xfc\xa9\xa9(\xfdo\xf7vH=\xf6\xd7\xbb\x0f\xc8Wv\xfcay\x97\xb4\xa3~\xbb\xbc\xab\x98r\xa6$\xa1E?\xba\xf7\xa0]\x16\xdd\x02\xbf\xb9\xbfC\xbe\xfa\xe6\xc3\xfb;\x89\xf3\x8bq\xed\xef\xad\x0f\xee\x08\xe8\xc8\xd2\xa1\x92\xdc\xc3\xeao\x92\xedj\xf4{D\xab\\z\x9c\x7f\xb6\xd7\x9b\xa2^ir{u{\xca\x06\xf1B' |
# write
#  16) | DEST: 14    0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b"?B\x18\xff\x11@\x96\x0e1\xe5]\x99\xe86\xc8\xf3\xd6\xe5W\xe8\xa9\xef\xa4\xba.!^:y\xc6\xe4\x84\xdckVey\xcb\x8fMi\xd9\xb0$a\x9d\x9cj\xd9\x16P\x8f\x14\xf5s:?m\x15\x04\xf1\x0c\x9e\xb7\xfe\xe69\x90X\xc8\rN5RE)\x13\x93\xff\x1c\xa8b?X\x10?\x11\xee\xa5F%VhI\x1b\xab@;)\x15\xf6\x06\xb9\xfeUwG'\x82\x07\xb3\xf2V\xea\x03r\xdcV\x99\xa0\x96KB\xa7 \x13\xf7**\xdf\n28P\r\xb2\xbd\xcd|\xff\x0fQNbo\xc5Ud\xce\x89\x0eFYq\xb82C\xa1\xd7\xe2\xeek\x12\xa6\xa3r \x7f\x0f\x8f\x9aG\xefA\xc2\xbd\xdc\x88\xf8Y\xf00\x89\xf6+\x16L\xa9;o\x17\xef\x862\x8d\xeaX\xa6\xe1\x89\x1e\xac\x90\x88\xe8%W\xca\xf6Wj\xf3\x07\xa4r\xefM\x1au\xa6\xe0\x16\xc7\xb9t\xc5\xac\x93j\x1b\xaa\x8ak\xaf3\xae\xe2\xa4\xcc\xf7\xad\x05r%\x99\xc3\x02\x8f\x00\xc9\x1cQ\x19\xb7q?" |
# write
#  17) | DEST: 15    0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b".\x7f\xecb{\xa37\x18\x1a\xc2\x1d\x85\x08\x00n\x1ceQ~\xbf\xf9\xc7\x0b\x83DO\xc5~.ir\x03\xe3w\xc7#:\xa0?\xe0*\xe7g=\xc2\xfa2\xe7\\\x8fd\x7f\x16A\x8f\x98\x9f)\xf3J\xb7snKU\x00.\x983*R*8\xac\xd0&\x90\x00\x82\x89\x93\xd4P\x8fcH\x14\x7f\xc3\xf0\x11\xd1\xd8;\x8e\x13%\xaf\xff\x1b(\x83*\xab\x1aZ\xdfVvY\x8c\xe3\xb6H\xb9\xf29\xfa\xc1\x85z\x82&prN*1uD\xc2\xa3*\xe7en~\x1c\x89\xa5\x1c\x1f\x14\xe3\xd1`\xff\xebq\x1a\xc8\xf1\x93\x8b\x1fr\x18U~\x8e\xdb\x17\xe3\xfcn`T\xabd\xe2!\xc7\x8dQ\xab;\xd9 \xc0g\xad\xea'\x83C6\xf0D\xf8P!?G(\xc9\x0f\x8d\xce=\x14\x8f\xaf\xa9>\xbf\xf8<\xb6\xfa\xee\xce\x06I\xf6\xf2\xf6&\x99\xbe\xb8\xd5#\xa7\xda\xc5~\x8f\xec\xfaw\xfb\xbd\x8c\xf2g\xdf\xde\xec\xa7v\xa94P\xd1\x8b\x1b}M\xbd%\xf8\xf6\xfa\x96\x06u" |
# write
#  18) | DEST: 16    0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b'\xd9\xbdgF\xb9\xef\xd5\xb5\x019\x1e\xd7V\xb7\xa9d\xb5\xb2\xbaM\xb6\xeb\xbd\x95mr*\\\\\xa1\xf3/0\xe5,\xaen\x93\xf4\xdc[\x1b\x90\xf6\xbfIo!{\xcf\xe3\xcd\xee\xd6\x8c\x1c\xf2\x01W\xf4\x03\xc3\x87h\xd5\x15\xec\xbe\x9d\xb6<8\xe5\xed\x91\xf5{\xa4}X\x11\x17"\xe9\x9f\xdf\xd8J\x81\x08ql6h\xcb\x82K\xefjZ}v\xa9C%\x06\xcb\xcc{H\xde\xb1\xfeu,?+\xd6\xa9\x8f\xf7/\xdd\x11\xa0A^p[P\x94\xfb\xdeI\xe8\x17:?\xa8\xd3+!\xdb\xb5\x8c\xec\xf7\x9eM\x8f\x8bZ\xab\xd1\xe5\xac2\xe5t\xeb4=\x83zF\xca\xcfVr\xb0\x83\x0e\xe3v\xaa[\xd4R\xd4\x1b\x02Z\x14\x7f\x8c\xb0\x15\xe7\xdd\x02V\x93\x87\xad\x14\xff~c\xf2e\xdd*?\xbf\x06\t\xb5\xcfJ\xf1~\x01\t\xf2\xfd\xc6\xf8\x81\xe0\xc1IF~^\x06I\xfaq5\x1b!\x8ck\x9f\xb0\xc1\x9c6E\xf6\x11\xda\x03\x87\xe7\x0f\x07\x96o|~\xce\x0f\xf5\x87\xd4' |
# write
#  19) | DEST: 17    0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b"\x82\xb8\xca\xac],\x08\xa41-\xbf\xe6\xc8\x83s]\xb9FU\x9c\xdf'\xfb\xfd\xb4\xa4\x8b:\xc3\x943\xceT\xed\xf3\x07\xdc\xf8.\xd0~\xdfw\xa8\xcc\x06\xcf3\x1d\xf0=8X\xe3\xc0x\x81\xc9?j\xfai&\xfd\x0c3\xe8\xce2\xf9\xb9\xf43L\xfa\x8b\x10j\xe0\x02\xe7\xdd+\xc4\x03\xf9\x99\x80a\xbc1\xe8\xe8\x1as\xa4\x85\x0bnT\xc4\x07Hp\xef\xa5\xe7\xe4\xf0\xa8\x065w\xae\x84\xa3\xb3\x02\x15Q\xa3\xcf/*\xf8O\xae\x83\x08F\x95q\xfb\x85\x8e\x9b]\xf1J\xe8\xd1\xa6\x93\x93\xbb*\xcfD\x18\x9d\xca\xf4\x98?\xd5\xf9\x0f_\xefI\xa5s|\xc3\xef\xea\xc4 7gV`T\x8fx\xd4\xf9\xf7\xb8\xf1\x85\x0f\xda\x1c\x13 \xba(\xf0Y\xe3g\xc5z\xd0W\xe9'\x98^\x80\x8c?s9\x8f\x15\\\xf9\xff\x07PK\x03\x04\x14\x00\x00\x00\x08\x00\x15\xab\x94L\x90\xcd[\xd4'\x00\x00\x00(\x00\x00\x00\x0c\x00\x00\x00rec_info.txt\xcb\xcdL" |
# write
#  20) | DEST: 18    0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b"\x89/I-.\xd1+\xc9LK\xab161\xab17\xb3\xa81\xae\xd151\xd23\xa814\x03\x91\xa6\x06z\x06\x00PK\x01\x02\x14\x03\x14\x00\x00\x00\x08\x00\x15\xab\x94L\xces\x84\xe0\xad\x11\x00\x00\x8cl\x00\x00\x08\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xa4\x81\x00\x00\x00\x00rec.tiffPK\x01\x02\x14\x03\x14\x00\x00\x00\x08\x00\x15\xab\x94L\x90\xcd[\xd4'\x00\x00\x00(\x00\x00\x00\x0c\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xa4\x81\xd3\x11\x00\x00rec_info.txtPK\x05\x06\x00\x00\x00\x00\x02\x00\x02\x00p\x00\x00\x00$\x12\x00\x00\x00\x00" |
# write
#  21) | DEST: END   0 | SRC: KM6QHN | DIGI: WIDE1 1WIDE2 1 | b'This is the end of transmission' |

# %%
st_replay.close()
st_replay.stop()

# %%
img = misc.imread("rec_calBlue.tiff")
plt.imshow(img)
# Out:
# /usr/lib/python3/dist-packages/PIL/TiffImagePlugin.py:697: UserWarning: Possibly corrupt EXIF data.  Expecting to read 1960 bytes but only got 1406. Skipping tag 34675
#   "Skipping tag %s" % (size, len(data), tag))
